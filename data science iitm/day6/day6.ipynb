# %%
class IITM:
    def intro():
        print('hello buddy!!')

    def say_hello():
        print('helowooowowowowow')

    def bye():
        print('byeyeyeyey')

# %%
a=int(45)
print(type(a))
# Out:
# <class 'int'>

# %%
ayan=IITM()  #instance creation, ayan is an instance of class iitm
print(type(ayan))
# Out:
# <class '__main__.IITM'>

# %%
class Remote:
    def __init__(self): # intit=initilization of class constructor it will work apne ,auto call hota hai ye message, magic method,dunder method
     print('object has been created')
     print('now you can use it')
    
    def volume_up(self):
      print('volume up by 1 unit')#... meaning pass for now we are not writing a code

    def volume_down(self):#class k andar method sirif class me he call kar sakte hai class k bahar nahi use kar sakte method and class k bahar function
      print('volume down by 1 unit')

    def power_on(self): # kya self hata k kuch aur likhge toh cod chlega? yes bass self ek likhne ka tareka hai bind karne k liye instance k sath
      print('power on') 
    def power_off(self): # these functions are known as features of class
      print('power off')
    
    def auto_suggest_channel(self):
        import time
        print('searching trending channel!!')
        time.sleep(3)
        print('youtube !! iitm')
        # what is class distructor =object ko distroy karta hai 
    def __del__(self):
        print('object has been deleted succesfllly')

# %%
mi = Remote()
print('done')
# Out:
# object has been created
# now you can use it
# done

# %%
mi.power_on()#when we are creating a method in any class the class automatically passes a object bina poche pass kar dete hai basically a default object is passed  so we pass a paramater in the function to avoid this problem
# Out:
# power on

# %%
mi.power_off()
# Out:
# power off

# %%
mi.volume_down()
# Out:
# volume down by 1 unit

# %%
mi.auto_suggest_channel()
# Out:
# searching trending channel!!
# youtube !! iitm

# %%
del(mi)# deleting object
# Out:
# object has been deleted succesfllly

# %%
mi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 mi
#
# NameError: name 'mi' is not defined

# %%
class Car:
    def __init__(self):
        #instance variabeles
        self.color='black'
        self.wheel=4
        self.spare_wheel=1#value of instance variable can be changed and mthod can not be changes according to unduvudyal needs
        self.airbag_support= True
        self.fuel_type='petrol'
        self.car_type='sedan'
        self.gear_type='automatic'
        print('your car is ready')

#================================================================================
#controlled features or methods
    def auto_park(self):
        import IPython
        url='''https://media.tenor.com/IWHNiM5l5rUAAAAM/parallel-parking-parking.gif'''  # ← this has a trailing space #kisi car parking ki gif ka link copy kar k paster karna hai
        display(IPython.display.Image(url))

    def engine_on(self):
        import pygame
        pygame.init()
        path='''C:\\Users\\niyati\\Downloads\\car-engine-335601.mp3 '''
                                                                # enigine on ka sound download kar k path dalna hai
        music=pygame.mixer.Sound(path)
        music.play()
        
    def speed_up(self):
        c=10
        while c<=200:
            import time
            print(f'speed is increasing by{c} km\hr')
            c+= 10
            display(clear =True)
            time.sleep(.5)

            if c>=100:
                print('you are crosing the limmit')
                break
    def drift_break(self,drift=False):   
          if drift ==True:
              import pygame
              pygame.init()
              path=r'''C:\\Users\\niyati\\Downloads\\-110063.mp3 '''
                                                                        # enigine on ka sound download kar k path dalna hai
              music=pygame.mixer.Sound(path)
              music.play()
              import IPython
              url='''https://tse2.mm.bing.net/th/id/OIP.2u78KiS1peWYfhlDCGi75AHaEJ?rs=1&pid=ImgDetMain&o=7&rm=3 ''' #kisi car parking ki gif ka link copy kar k paster karna hai
              display(IPython.display.Image(url))
          else: 
              print('break applied')

# %%
bmw=Car()
# Out:
# your car is ready

# %%
bmw.drift_break()
# Out:
# break applied

# %%
bmw.engine_on()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
bmw.auto_park()

# %%
kia=Car()
# Out:
# your car is ready

# %%
kia.color
# Out:
# 'black'

# %%
tata =Car()
# Out:
# your car is ready

# %%
maruti=Car()
# Out:
# your car is ready

# %%
tata.color
# Out:
# 'black'

# %%
tata.color='white'

# %%
tata.color
# Out:
# 'white'

# %%
maruti.color
# Out:
# 'black'

# %%
maruti.gear_type='manual'

# %%
maruti.gear_type
# Out:
# 'manual'

# %%
#access modifiers public private and protected 
#public
class ATM:
    
    def __init__(self):
        print('object created successfully')
        self.pin=111 #public variable
        self .balance=2000

    def change_pin(self):
         self.pin = input('enter new pin')
         print('your pin has been changed ')
    def show_balance(self):
         print(f''' your balance current balance is rs {self.balance}''')
    def atm_performance_status(self):
         print('atm is working fine')

# %%
i= ATM()
# Out:
# object created successfully

# %%
i.show_balance()
# Out:
#  your balance current balance is rs 2000

# %%
i.balance
# Out:
# 2000

# %%
i.atm_performance_status()
# Out:
# atm is working fine

# %%
#access modifiers public private and protected
class ATM_version_1:
    #protected _
    def __init__(self):
        print('object created successfully')
        self._pin=111#using the underscore beflre any variable we can make it private so it can not be accessed
        self._balance=2000

    def change_pin(self):
         self._pin = input('enter new pin')
         print('your pin has been changed ')
    def show_balance(self):
         print(f''' your balance current balance is rs {self._balance}''')
    def atm_performance_status(self):
         print('atm is working fine')

# %%
s=ATM_version_1()
# Out:
# object created successfully

# %%
s.show_balance()
# Out:
#  your balance current balance is rs 2000

# %%
s._pin #we can still use the so called private variables
# Out:
# 111

# %%
#access modifiers public private and protected
class ATM_version_2:
    #private __
    def __init__(self):
        print('object created successfully')
        self.__pin=111 #using the underscore beflre any variable we can make it private so it can not be accessed
        self.__balance=2000

    def change_pin(self):
         self.__pin = input('enter new pin')
         print('your pin has been changed ')
    def show_balance(self):
         print(f''' your balance current balance is rs {self.__balance}''')
    def __atm_performance_status(self):#private method
         print('atm is working fine')

# %%
#in python encapsulation is only a concept it is not used

# %%
i=ATM_version_2()
# Out:
# object created successfully

# %%
i._ATM_version_2__atm_performance_status()
# Out:
# atm is working fine

# %%
#private k liye__ and protected k liye _

# %%
#python to mysql import pymysql
#shift+tab to see the info about what to enter

# %%
#pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql as py
print('done')
# Out:
# done

# %%
conn=py.connect(user='root',
           password='@Tintinsingh06',
          host='localhost',
          autocommit='True'#changes will be saved autoomatically in the database
          )
print('connection created')
print('done')
# Out:
# connection created
# done

# %%
#creating database using python
cur=conn.cursor()#we need a connection to create a cursor 
print('done')
# Out:
# done

# %%
query='''  create database iitm_day5; '''
cur.execute(query)
print('done')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[43], line 2
#       1 query='''  create database iitm_day5; '''
# ----> 2 cur.execute(query)
#       3 print('done')
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
# ...

# %%
query =''' USE iitm_day5;'''
cur.execute(query)
print('done')
# Out:
# done

# %%
query=''' create table student_details
(
SID int not null,
student_name varchar(50),
course varchar(50),
address varchar(100),
scholarship float
);'''
cur.execute(query)
print('done')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[45], line 9
#       1 query=''' create table student_details
#       2 (
#       3 SID int not null,
#    (...)
#       7 scholarship float
#       8 );'''
# ----> 9 cur.execute(query)
#      10 print('done')
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
# ...

# %%
query= ''' insert into student_details
values 
(101,"tintin","bca","delhi",5000),
(105,"pingu","mca","noida",1000);

'''
cur.execute(query)
# Out:
# 2

# %%
sid= int(input('enter roll no/SID:  '))
name=input('enter your name:  ')
course=input('enter your course:  ')
address=input('enter your address:  ')
scholarship=float(input('enter your scholarship ammount:  '))

q=f''' insert into student_details values 
({sid},'{name}','{course}','{address}',{scholarship});''' # using single quote before and after name course address coz they are declared as varchar if not used it will generatean error
cur.execute(q)
print('done')
# Out:
# enter roll no/SID:   113
# enter your name:   dw
# enter your course:   efqw
# enter your address:   efw
# enter your scholarship ammount:   123
# done

# %%
#taking input from the user with only n number of inputs
# n=3
for i in range(n):
    sid= int(input('enter roll no/SID:  '))
    name=input('enter your name:  ')
    course=input('enter your course:  ')
    address=input('enter your address:  ')
    scholarship=float(input('enter your scholarship ammount:  '))
    
    
    q=f''' insert into student_details values 
    ({sid},'{name}','{course}','{address}',{scholarship});''' # using single quote before and after name course address coz they are declared as varchar if not used it will generatean error
    cur.execute(q)
    print('record inserted successfully')
print('done')

# %%
 query =''' select * from student_details;'''
cur.execute(query)
records=cur.fetchall()

all_columns=[]
for i in cur.description:
    all_columns.append(i[0])

    
import pandas as pd
df=pd.DataFrame(records,columns=all_columns)
df
# Out:
#      SID student_name course address  scholarship
# 0    101       niyati    bca   delhi       5000.0
# 1    101       niyati    bca   delhi       5000.0
# 2    101       niyati    bca   delhi       5000.0
# 3    105     kushagra    mca   noida       1000.0
# 4    101       niyati    bca   delhi       5000.0
# 5    105        pingu    mca   noida       1000.0
# 6    101       tintin    bca   delhi       5000.0
# 7    105        pingu    mca   noida       1000.0
# 8    101       tintin    bca   delhi       5000.0
# 9    105        pingu    mca   noida       1000.0
# 10    12           eq     qw     qew         12.0
# 11   123          sda    wdq    qwdq        123.0
# 12    12          rqr    rgw      qf        131.0
# 13   113           dw   efqw     efw        123.0
# 14   106         ewqe     wq    eqwe       1231.0
# 15   213         ewre    rwe     ewr        313.0
# 16   123         gwwf     we      wf         34.0
# 17  1231          wef   gwrg     wgr         31.0
# ...

# %%
def show_records(db,table):
    query =f''' select * from {db}.{table};'''
    cur.execute(query)
    
    records=cur.fetchall()
    
    all_columns=[]
    for i in cur.description:
        all_columns.append(i[0])
    
        
    import pandas as pd
    df=pd.DataFrame(records,columns=all_columns)
    return df

# %%
show_records('iitm_day5','student_details')
# Out:
#      SID student_name course address  scholarship
# 0    101       niyati    bca   delhi       5000.0
# 1    101       niyati    bca   delhi       5000.0
# 2    101       niyati    bca   delhi       5000.0
# 3    105     kushagra    mca   noida       1000.0
# 4    101       niyati    bca   delhi       5000.0
# 5    105        pingu    mca   noida       1000.0
# 6    101       tintin    bca   delhi       5000.0
# 7    105        pingu    mca   noida       1000.0
# 8    101       tintin    bca   delhi       5000.0
# 9    105        pingu    mca   noida       1000.0
# 10    12           eq     qw     qew         12.0
# 11   123          sda    wdq    qwdq        123.0
# 12    12          rqr    rgw      qf        131.0
# 13   113           dw   efqw     efw        123.0
# 14   106         ewqe     wq    eqwe       1231.0
# 15   213         ewre    rwe     ewr        313.0
# 16   123         gwwf     we      wf         34.0
# 17  1231          wef   gwrg     wgr         31.0
# ...
